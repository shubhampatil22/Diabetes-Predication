# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\shubh\OneDrive\Desktop\Datasets\diabetes.csv")

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
(df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI']]==0).sum()
# Out:
# Pregnancies      111
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI']]=df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   657.000000  763.000000     733.000000     541.000000  394.000000
# mean      4.494673  121.686763      72.405184      29.153420  155.548223
# std       3.217291   30.535641      12.382158      10.476982  118.775855
# min       1.000000   44.000000      24.000000       7.000000   14.000000
# 25%       2.000000   99.000000      64.000000      22.000000   76.250000
# 50%       4.000000  117.000000      72.000000      29.000000  125.000000
# 75%       7.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
df['Pregnancies']=df['Pregnancies'].fillna(df['Pregnancies'].mean())

# %%
df['Glucose']=df['Glucose'].fillna(df['Glucose'].mean())
df['BloodPressure']=df['BloodPressure'].fillna(df['BloodPressure'].mean())
df['SkinThickness']=df['SkinThickness'].fillna(df['SkinThickness'].mean())
df['Insulin']=df['Insulin'].fillna(df['Insulin'].mean())
df['BMI']=df['BMI'].fillna(df['BMI'].mean())

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.countplot(df['Outcome'])

# %%
sns.pairplot(df)

# %%
df.corr()*100
# Out:
#                           Pregnancies     Glucose  BloodPressure  \
# Pregnancies                100.000000   15.429004      25.911741
# Glucose                     15.429004  100.000000      21.836692
# BloodPressure               25.911741   21.836692     100.000000
# SkinThickness               13.181913   19.299109      19.281584
# Insulin                      6.807676   42.015709       7.251688
# BMI                         11.058979   23.094124      28.126771
# DiabetesPedigreeFunction    -0.565824   13.705971      -0.276336
# Age                         51.166244   26.653352      32.459494
# Outcome                     24.826293   49.292767      16.607367
#
#                           SkinThickness     Insulin         BMI  \
# Pregnancies                   13.181913    6.807676   11.058979
# Glucose                       19.299109   42.015709   23.094124
# BloodPressure                 19.281584    7.251688   28.126771
# ...

# %%
sns.boxplot(df['Glucose'])

# %%
sns.boxplot(df['Pregnancies'])

# %%
df['Pregnancies'].shape
# Out:
# (768,)

# %%
min_thresold,max_thresold=df['Pregnancies'].quantile([0.05,0.95])

# %%
min_thresold,max_thresold
# Out:
# (1.0, 10.0)

# %%
df1=df[(df['Pregnancies']>=min_thresold) & (df['Pregnancies']<=max_thresold)]

# %%
df1['Pregnancies'].shape
# Out:
# (734,)

# %%
sns.boxplot(df1['Pregnancies'])

# %%
sns.boxplot(df1['BloodPressure'])

# %%
df1['BloodPressure'].shape
# Out:
# (734,)

# %%
min_thresold,max_thresold=df1['BloodPressure'].quantile([0.05,0.95])
df1=df1[(df1['BloodPressure']>=min_thresold) & (df1['BloodPressure']<=max_thresold)]
sns.boxplot(df1['BloodPressure'])

# %%
df1['BloodPressure'].shape
# Out:
# (670,)

# %%
sns.boxplot(df1['SkinThickness'])

# %%
min_thresold,max_thresold=df1['SkinThickness'].quantile([0.10,0.90])
df1=df1[(df1['SkinThickness']>=min_thresold) & (df1['SkinThickness']<=max_thresold)]
sns.boxplot(df1['SkinThickness'])

# %%
df1['SkinThickness'].shape
# Out:
# (542,)

# %%
df1.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#df1['BMI']=df1['BMI'].fillna(df1['BMI'].mean())

# %%
sns.boxplot(df1['BMI'])

# %%
min_thresold,max_thresold=df1['BMI'].quantile([0.05,0.95])
df1['BMI']=df1[(df1['BMI']>=min_thresold) & (df1['BMI']<=max_thresold)]
sns.boxplot(df1['BMI'])

# %%
df1['BMI'].shape
# Out:
# (542,)

# %%
df1['BMI']=df1['BMI'].fillna(df1['BMI'].mean())

# %%
df1.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.scatterplot(x=df.Age,y=df.Outcome,data=df)

# %%
X=df1.iloc[:,0:8]
y=df1.iloc[:,8]

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
pred=lr.predict(X_test)
acc_log=accuracy_score(y_test,pred)*100

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(X_test,y_test)
pred1=knn.predict(X_test)
acc_knn=accuracy_score(y_test,pred1)*100

# %%
confusion_matrix(y_test,pred1)
# Out:
# array([[115,   0],
#        [ 30,  34]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
des=DecisionTreeClassifier()
des.fit(X_test,y_test)
pred2=des.predict(X_test)
acc_des=accuracy_score(y_test,pred2)*100

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,pred2)
# Out:
# array([[115,   0],
#        [  0,  64]], dtype=int64)

# %%
from sklearn.svm import SVC
Sv=SVC()
Sv.fit(X_test,y_test)
pred3=Sv.predict(X_test)
confusion_matrix(y_test,pred3)
# Out:
# array([[115,   0],
#        [  0,  64]], dtype=int64)

# %%
acc_Sv=accuracy_score(y_test,pred3)*100

# %%
from sklearn.ensemble import RandomForestClassifier
rand=RandomForestClassifier(n_estimators=100)
rand.fit(X_train,y_train)
pred4=rand.predict(X_test)
acc_rand=accuracy_score(y_test,pred4)*100

# %%
Models=pd.DataFrame({"Model":["Logistic Regression","KNeighborsClassifier","DecisionTree","Support Vector","Random Forest"],
                     "Score":[acc_log,acc_knn,acc_des,acc_Sv,acc_rand]})

# %%
Models.sort_values(by='Score',ascending=False)
# Out:
#                   Model       Score
# 2          DecisionTree  100.000000
# 3        Support Vector  100.000000
# 1  KNeighborsClassifier   83.240223
# 0   Logistic Regression   78.770950
# 4         Random Forest   77.094972

# %%
# Prediction 1
# Input sequence: Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DPF, Age
prediction = des.predict([[4, 81, 72, 25, 76, 30.1, 0.547, 30]])[0]
if prediction==1:
  print('Oops! You have diabetes.')
else:
  print("Great! You don't have diabetes.")
# Out:
# Great! You don't have diabetes.

# %%
# Prediction 2
# Input sequence: Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DPF, Age
prediction = des.predict([[2, 117, 88, 24, 195, 34.5, 0.403, 40]])[0]
if prediction:
  print('Oops! You have diabetes.')
else:
  print("Great! You don't have diabetes.")
# Out:
# Oops! You have diabetes.
